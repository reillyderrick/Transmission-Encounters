# %%
import pandas as pd

df = pd.read_csv('pio11_results.csv')

df = df.sort_values(by=['dist'])
print(df)
df.to_csv('pio11_results.csv')
# Out:
#      Unnamed: 0  Unnamed: 0.1            source_id          ra        dec  \
# 215         215          1859   640862653425455360  145.260767  22.022373
# 124         124          1126   129200553364168064   42.956808  29.486212
# 370         370          3491  4171266057417283328  270.172072  -7.285027
# 369         369          3479  4171266057429634048  270.170331  -7.284101
# 255         255          2178  3691265460219482240  198.373198   1.315695
# ..          ...           ...                  ...         ...        ...
# 149         149          1315  3453717240054610560   92.647267  35.991274
# 217         217          1880   627273896202321664  148.347236  19.029658
# 98           98           905  2589367754771960192   24.418902  15.585084
# 324         324          2792  4357293834175012352  247.705593  -4.067343
# 267         267          2333  3664057353499743360  207.099645   1.259035
#
#          g_abs     bp_rp   parallax  parallax_error       dist  \
# ...

# %%
sig_df = df
sig_df['reach_time_years'] = df['dist']*3.26
sig_df['reach_time_days'] = sig_df['reach_time_years'] * 365.24
sig_df['year'] = sig_df['date'].str[:4]
sig_df['reach_year'] = sig_df['year'].astype(int) + sig_df['reach_time_years'] #approximate reach year
sig_df['return_year'] = sig_df['reach_year'] + sig_df['reach_time_years']

sig_df = sig_df.sort_values(by=['reach_year'])
print(sig_df)
sig_df.to_csv('pio11_results.csv')
# Out:
#      Unnamed: 0  Unnamed: 0.1            source_id          ra        dec  \
# 215         215          1859   640862653425455360  145.260767  22.022373
# 124         124          1126   129200553364168064   42.956808  29.486212
# 255         255          2178  3691265460219482240  198.373198   1.315695
# 107         107           975   100380639907919872   33.074556  21.982406
# 66           66           580  2631967439437024384  349.786950  -6.220944
# ..          ...           ...                  ...         ...        ...
# 361         361          3319  4170852808549696000  269.708401  -7.728276
# 324         324          2792  4357293834175012352  247.705593  -4.067343
# 368         368          3467  4171194894104141952  270.913217  -7.366584
# 356         356          3240  4174845169631404288  267.176120  -6.942096
# 373         373          3557  4170902664529325184  271.314994  -8.181219
#
#          g_abs     bp_rp   parallax  parallax_error       dist  ...  \
# ...

# %%
sig_df.head(20)
# Out:
#      Unnamed: 0  Unnamed: 0.1            source_id          ra        dec  \
# 215         215          1859   640862653425455360  145.260767  22.022373
# 124         124          1126   129200553364168064   42.956808  29.486212
# 255         255          2178  3691265460219482240  198.373198   1.315695
# 107         107           975   100380639907919872   33.074556  21.982406
# 66           66           580  2631967439437024384  349.786950  -6.220944
# 370         370          3491  4171266057417283328  270.172072  -7.285027
# 369         369          3479  4171266057429634048  270.170331  -7.284101
# 334         334          2919  4360275817086026624  260.662550  -7.074798
# 146         146          1287   183132839955842560   83.647098  35.551495
# 333         333          2906  4360275817088229632  260.662066  -7.074838
# 168         168          1463   919034563674060544  117.193493  36.670534
# 343         343          3028  4361790394355496576  261.680410  -6.665739
# ...

# %%
e_df = pd.read_csv('pio11_results_error.csv')   #sorting results with error included

e_df = e_df.sort_values(by=['dist'])
print(e_df)

e_df.to_csv('pio11_results_error.csv')
# Out:
#      Unnamed: 0  Unnamed: 0.1            source_id          ra        dec  \
# 230         230          1859   640862653425455360  145.260767  22.022373
# 136         136          1126   129200553364168064   42.956808  29.486212
# 35           35           255  6768045340904025088  294.653889 -24.282592
# 273         273          2164  3702983196155254016  193.094472   2.867039
# 395         395          3491  4171266057417283328  270.172072  -7.285027
# ..          ...           ...                  ...         ...        ...
# 163         163          1315  3453717240054610560   92.647267  35.991274
# 233         233          1880   627273896202321664  148.347236  19.029658
# 106         106           905  2589367754771960192   24.418902  15.585084
# 345         345          2792  4357293834175012352  247.705593  -4.067343
# 288         288          2333  3664057353499743360  207.099645   1.259035
#
#          g_abs     bp_rp   parallax  parallax_error       dist  \
# ...

# %%
e_df['reach_time_years'] = e_df['dist']*3.26
e_df['reach_time_days'] = e_df['reach_time_years'] * 365.24
e_df['year'] = e_df['date'].str[:4]
e_df['reach_year'] = e_df['year'].astype(int) + e_df['reach_time_years'] #approximate reach year
e_df['return_year'] = e_df['reach_year'] + e_df['reach_time_years']

e_df = e_df.sort_values(by=['reach_year'])
print(e_df)
e_df.to_csv('pio11_results_error.csv')
# Out:
#      Unnamed: 0  Unnamed: 0.1            source_id          ra        dec  \
# 230         230          1859   640862653425455360  145.260767  22.022373
# 136         136          1126   129200553364168064   42.956808  29.486212
# 35           35           255  6768045340904025088  294.653889 -24.282592
# 273         273          2164  3702983196155254016  193.094472   2.867039
# 275         275          2178  3691265460219482240  198.373198   1.315695
# ..          ...           ...                  ...         ...        ...
# 386         386          3319  4170852808549696000  269.708401  -7.728276
# 345         345          2792  4357293834175012352  247.705593  -4.067343
# 393         393          3467  4171194894104141952  270.913217  -7.366584
# 381         381          3240  4174845169631404288  267.176120  -6.942096
# 398         398          3557  4170902664529325184  271.314994  -8.181219
#
#          g_abs     bp_rp   parallax  parallax_error       dist  ...  \
# ...
